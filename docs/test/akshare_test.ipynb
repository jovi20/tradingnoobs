# %%
import akshare as ak
stock_us_hist_df = ak.stock_us_hist(symbol='104.NVDA', period="daily", start_date="20260210", end_date="20260210", adjust="qfq")
print(stock_us_hist_df)

# %%
#from akshare_one import get_realtime_data
import akshare_one
# 港股代码例如“00700”表示腾讯控股
df_hk = akshare_one.get_basic_info(symbol="600519", source="eastmoney")

print(df_hk)
# Out:
# item    price  symbol  name  total_shares  float_shares  total_market_cap  \
# 0     1503.26  600519  贵州茅台  1.252270e+09  1.252270e+09      1.882488e+12
#
# item  float_market_cap industry listing_date
# 0         1.882488e+12     酿酒行业   2001-08-27

# %%
import akshare as ak
cookie = "8e9b5875b5bce0c13ab91c86d4c4a34a6ace5dbe"

stock_individual_basic_info_hk_xq_df = ak.stock_individual_basic_info_hk_xq(symbol="00700",token=cookie)
print(stock_individual_basic_info_hk_xq_df)
# Out:
#            item                                              value
# 0       comunic                                        200079465.0
# 1     comcnname                                           腾讯控股有限公司
# 2     comenname                           Tencent Holdings Limited
# 3       incdate                                     943286400000.0
# 4        rgiofc  Cricket Square, Hutchins Drive, P.O.Box 2681, ...
# 5    hofclctmbu                               中国深圳市南山区科技园科技中一路腾讯大厦
# 6      chairman                                                马化腾
# 7           mbu                     集团的主要业务包括提供互联网及移动增值服务以及网络广告服务。
# 8       comintr      腾讯公司成立于1998年11月,是目前中国最大的互联网综合服务提供商之一,也是中国服...
# 9     refccomty                                                1.0
# 10     numtissh                                        420160500.0
# 11         ispr                                                3.7
# 12         nrfd                                       1437800000.0
# ...
